# %% [markdown]
# # Fashion Attribute Recognition - Sanitized Research Provenance
#
# This notebook is intentionally sanitized for the public repository. Colab execution outputs, personal runtime metadata, local Drive paths, and generated image payloads were removed.
#
# The production inference implementation lives in `src/models/fashion_multihead.py` and `src/inference/api`. Runtime checkpoints and the local DINOv2 hub checkout are mounted from `/models/fashion/current` on the deployment host, not committed to git.

# %%
LABEL_MAPS = {
    "material": ["cotton", "silk_satin", "leather", "synthetic", "denim", "knitwear"],
    "color": ["black", "white", "red", "navy", "beige", "blue", "green", "yellow", "grey", "brown", "pink", "purple"],
    "pattern": ["solid", "striped", "checkered_plaid", "floral", "geometric", "animal_print"],
    "texture": ["smooth", "rough_coarse", "fluffy_furry", "ribbed_structured", "sheer"],
}

# Production code: src/models/fashion_multihead.py
# API code: src/inference/api
